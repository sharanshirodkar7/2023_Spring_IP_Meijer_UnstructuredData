# %%
import pandas as pd
import numpy as np

# %%
desc=pd.read_csv('results.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
len(desc)
# Out:
# 784

# %%
desc.head()
# Out:
#         ItemSku                                        ProductName  \
# 0  6.431942e+09  AG CARD VALENTINE FEEL THE LOVE               ...
# 1  4.119674e+09  PROGRESSO RED SODIUM CHICKEN N WILD RICE 18.5 ...
# 2  2.310015e+09  PEDIGREE DRY DOG COMPL CHKN VEG 18LB          ...
# 3  8.130800e+09  JP CHENET BLANC DE BLANC 750 ML               ...
# 4  6.193444e+10  2022 DESKPAD CAL ACADEMIC YR WATERCOLOR MED   ...
#
#                                        MarketingName  \
# 0  American Greetings Feel the Love Valentine's D...
# 1  Progresso Heart Healthy Reduced Sodium Chicken...
# 2  Pedigree Adult Complete Nutrition Dry Dog Food...
# 3               JP Chenet Blanc de Blanc Brut, 750ML
# 4  July 2021 - June 2022 Watercolor Painted Block...
#
#                                     MarketingDetails  \
# 0  Front Message: Feel the Love    Inside message...
# 1  Progresso Heart Healthy Chicken Wild Rice Soup...
# 2  PEDIGREE® Adult Complete Nutrition for Dogs ha...
# ...

# %%
desc['text_x'].head()
# Out:
# 0    Product Name:American Greetings Feel the Love ...
# 1    Product Name:Progresso Heart Healthy Reduced S...
# 2    Product Name:Pedigree Adult Complete Nutrition...
# 3    Product Name:JP Chenet Blanc de Blanc Brut, 75...
# 4    Product Name:July 2021 - June 2022 Watercolor ...
# Name: text_x, dtype: object

# %%
#!pip install transformers

import tensorflow as tf
from transformers import TFGPT2LMHeadModel, GPT2Tokenizer

model = TFGPT2LMHeadModel.from_pretrained("gpt2")

# Load pre-trained model tokenizer (vocabulary)
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# Define a prompt for text generation
prompt = desc['text_x'][2]

# Encode the prompt
encoded_prompt = tokenizer.encode(prompt, add_special_tokens=True)
encoded_prompt = tf.expand_dims(encoded_prompt, 0)

# Generate text with the model
output_sequences = model.generate(
    input_ids=encoded_prompt,  # pass the input as a Tensor with shape [batch_size, sequence_length]
    max_length=len(encoded_prompt[0])+121,  # maximum length of the generated text
    temperature=1.0,  # controls the randomness of the generated text
    top_k=0,  # controls the diversity of the generated text
    top_p=0.9,  # controls the diversity of the generated text
    repetition_penalty=1.0,  # penalizes repetition in the generated text
    do_sample=True,  # enables text generation
    num_return_sequences=1  # number of independently generated sequences to return
)

# Decode the generated output
generated_text = tokenizer.decode(output_sequences[0], clean_up_tokenization_spaces=True)

# Print the generated text
print(generated_text)
# Out:
# ...
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at gpt2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.
# ...
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Product Name:Pedigree Adult Complete Nutrition Dry Dog Food - 20.4lbDont miss this in the Product Description
#
#   information on the product
# ...

# %%
desc['text_x'][2]
# Out:
# 'Product Name:Pedigree Adult Complete Nutrition Dry Dog Food - 20.4lbDont miss this in the Product Description \n\n  information on the product \n Pedigree ADULT complete nutrition 100% COMPLETE AND BALANCED FOR HEALTH & VITALITY FORMULATED FOR THE 4 UNIVERSAL NEEDS OF ALL DOGS 0 NOW WITH OPTIMAL LEVELS OF MINERALS & OILS ESSENTIAL TO NEW! NOURISH SKIN & COAT IMPROVED FORMULA NET WT 9.07 kg (20 1b) FOOD FOR JULY'

# %%
import nltk

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# True

# %%
import torch
from transformers import BertTokenizer, BertForMaskedLM, pipeline

# load pre-trained BERT model and tokenizer
model_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForMaskedLM.from_pretrained(model_name)

# fine-tune BERT model on your training data
# ...
# you can use the Hugging Face Transformers library to fine-tune the model on your dataset

# use BERT to generate text based on a prompt
prompt = 'Product Name:Pedigree Adult Complete Nutrition Dry Dog Food - 20.4lbDont miss this in the Product Description \n\n  information on the product \n Pedigree ADULT complete nutrition 100% COMPLETE AND BALANCED FOR HEALTH & VITALITY FORMULATED FOR THE 4 UNIVERSAL NEEDS OF ALL DOGS 0 NOW WITH OPTIMAL LEVELS OF MINERALS & OILS ESSENTIAL TO NEW! NOURISH SKIN & COAT IMPROVED FORMULA NET WT 9.07 kg (20 1b) FOOD FOR JULY'
generator = pipeline('text-generation', model=model, tokenizer=tokenizer)
generated = generator(prompt, max_length=121, num_return_sequences=1)
print(generated[0]['generated_text'])
# Out:
# ...
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification, AdamW
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from sklearn.metrics import accuracy_score

# Load the pre-trained BERT model and tokenizer
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Prepare the training data
train_texts = ['example sentence romeo', 'example sentence juliet']
train_labels = [0, 1]

train_encodings = tokenizer(train_texts, truncation=True, padding=True)
train_dataset = torch.utils.data.TensorDataset(torch.tensor(train_encodings['input_ids']),
                                               torch.tensor(train_encodings['attention_mask']),
                                               torch.tensor(train_labels))
train_sampler = RandomSampler(train_dataset)
train_dataloader = DataLoader(train_dataset, sampler=train_sampler, batch_size=32)

# Fine-tune the BERT model
optimizer = AdamW(model.parameters(), lr=5e-5)
epochs = 3
for epoch in range(epochs):
    for batch in train_dataloader:
        optimizer.zero_grad()
        input_ids = batch[0].to(device)
        attention_mask = batch[1].to(device)
        labels = batch[2].to(device)
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        loss.backward()
        optimizer.step()

# Evaluate the fine-tuned BERT model
test_texts = ['example sentence why not', 'example sentence what if']
test_labels = [0, 1]

test_encodings = tokenizer(test_texts, truncation=True, padding=True)
test_dataset = torch.utils.data.TensorDataset(torch.tensor(test_encodings['input_ids']),
                                              torch.tensor(test_encodings['attention_mask']),
                                              torch.tensor(test_labels))
test_sampler = SequentialSampler(test_dataset)
test
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
print(prompt)
# Out:
# Product Name:Pedigree Adult Complete Nutrition Dry Dog Food - 20.4lbDont miss this in the Product Description
#
#   information on the product
#  Pedigree ADULT complete nutrition 100% COMPLETE AND BALANCED FOR HEALTH & VITALITY FORMULATED FOR THE 4 UNIVERSAL NEEDS OF ALL DOGS 0 NOW WITH OPTIMAL LEVELS OF MINERALS & OILS ESSENTIAL TO NEW! NOURISH SKIN & COAT IMPROVED FORMULA NET WT 9.07 kg (20 1b) FOOD FOR JULY

# %%
#pip install torch==1.9.0+cpu torchvision==0.10.0+cpu torchaudio==0.9.0 -f https://download.pytorch.org/whl/cu111/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu111/torch_stable.html
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rllib3 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -raitlets (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rllib3 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -raitlets (c:\programdata\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement torch==1.9.0+cpu (from versions: 1.7.1, 1.8.0, 1.8.0+cu111, 1.8.1, 1.8.1+cu111, 1.9.0, 1.9.0+cu111, 1.9.1, 1.9.1+cu111, 1.10.0, 1.10.0+cu111, 1.10.1, 1.10.1+cu111, 1.10.2, 1.10.2+cu111, 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1)
# ERROR: No matching distribution found for torch==1.9.0+cpu
# WARNING: Ignoring invalid distribution -rllib3 (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
#pip install torch torchvision torchaudio

# %%
import torch
#print(torch.__version__)

# %%
#pip install numpy --pre torch --force-reinstall --index-url https://download.pytorch.org/whl/nightly/cu117

# %%
#pip install --pre torch --index-url https://download.pytorch.org/whl/nightly/cpu

# %%
len(desc)
# Out:
# 784

# %% [markdown]
# #NEW BERT

# %%
desc.columns
# Out:
# Index(['ItemSku', 'ProductName', 'MarketingName', 'MarketingDetails',
#        'MarketingFeatures', 'L6_Name', 'ItemDocumentValue', 'text_x', 'text_y',
#        'Product_Description', 'MarketingDetails_c'],
#       dtype='object')

# %%
data= desc[['MarketingDetails','text_x']]
data.head()
# Out:
#                                     MarketingDetails  \
# 0  Front Message: Feel the Love    Inside message...
# 1  Progresso Heart Healthy Chicken Wild Rice Soup...
# 2  PEDIGREE® Adult Complete Nutrition for Dogs ha...
# 3             World's number 1 French Sparkling Wine
# 4  Enjoy illustrated rainbow paint with this 12-m...
#
#                                               text_x
# 0  Product Name:American Greetings Feel the Love ...
# 1  Product Name:Progresso Heart Healthy Reduced S...
# 2  Product Name:Pedigree Adult Complete Nutrition...
# 3  Product Name:JP Chenet Blanc de Blanc Brut, 75...
# 4  Product Name:July 2021 - June 2022 Watercolor ...

# %%
data = data.applymap(lambda x: x.replace('.', ' ') if isinstance(x, str) else x)

# %%
# for i in data['MarketingDetails']:
#     print(i,'\n\n\n')

# %%
data1=data[0:1]
data1
# Out:
#                                     MarketingDetails  \
# 0  Front Message: Feel the Love    Inside message...
#
#                                               text_x
# 0  Product Name:American Greetings Feel the Love ...

# %%
# Load the BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)

# Tokenize the input text and target descriptions
text_x = data['text_x'].tolist()
marketing_details = data['MarketingDetails'].tolist()

# %%
label_dict = {label: i for i, label in enumerate(set(marketing_details))}
labels = [label_dict[label] for label in marketing_details]

# Convert the labels to a tensor
labels_tensor = torch.tensor(labels)

# %%
input_ids = []
attention_masks = []
for text in text_x:
    encoded_dict = tokenizer.encode_plus(
                        text,                      # Text to encode
                        add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                        max_length = 128,           # Pad or truncate all sentences
                        truncation=True,
                        pad_to_max_length = True,
                        return_attention_mask = True,   # Construct attn. masks
                        return_tensors = 'pt',     # Return pytorch tensors
                   )
    input_ids.append(encoded_dict['input_ids'])
    attention_masks.append(encoded_dict['attention_mask'])
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py:2346: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
input_ids = torch.cat(input_ids, dim=0)
attention_masks = torch.cat(attention_masks, dim=0)

# %%
from sklearn.model_selection import train_test_split

train_inputs, validation_inputs, train_labels, validation_labels = train_test_split(input_ids, labels, 
                                                            random_state=2022, test_size=0.1)
train_masks, validation_masks, _, _ = train_test_split(attention_masks, input_ids,
                                             random_state=2022, test_size=0.1)

# %%
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=1,
                                                      output_attentions=False, output_hidden_states=False)

model.cuda()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
from transformers import (GPT2Config, GPT2LMHeadModel, GPT2DoubleHeadsModel,
                                  AdamW, get_linear_schedule_with_warmup)

# %%
optimizer = AdamW(model.parameters(),
                  lr = 2e-5, # args.learning_rate - default is 5e-5
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )

# Set up the learning rate scheduler
epochs = 4
total_steps = len(train_inputs) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0,
                                            num_training_steps = total_steps)

# Train the model
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

batch_size = 32

# %%
import torch

train_inputs = torch.tensor(train_inputs)
train_masks = torch.tensor(train_masks)
train_labels = torch.tensor(train_labels)
# Out:
# <ipython-input-65-6c84e13fe203>:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_inputs = torch.tensor(train_inputs)
# <ipython-input-65-6c84e13fe203>:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_masks = torch.tensor(train_masks)
# <ipython-input-65-6c84e13fe203>:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_labels = torch.tensor(train_labels)

# %%
# Create the DataLoader for our training set
train_data = TensorDataset(train_inputs, train_masks, train_labels)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

# %%
validation_inputs = torch.tensor(validation_inputs)
validation_masks = torch.tensor(validation_masks)
validation_labels = torch.tensor(validation_labels)
# Out:
# <ipython-input-67-2ff5b2c8c0b4>:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   validation_inputs = torch.tensor(validation_inputs)
# <ipython-input-67-2ff5b2c8c0b4>:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   validation_masks = torch.tensor(validation_masks)

# %%
# Create the DataLoader for our validation set
validation_data = TensorDataset(validation_inputs, validation_masks, validation_labels)
validation_sampler = SequentialSampler(validation_data)
validation_dataloader = DataLoader(validation_data, sampler=validation_sampler, batch_size=batch_size)

# %%
# Set the seed value for reproducibility
seed_val = 2022

# Train the model
from tqdm import tqdm, trange

# Store the average loss after each epoch so we can plot them
loss_values = []

for epoch in trange(epochs, desc="Epoch"):
    # ========================================
    #               Training
    # ========================================
    # Perform one full pass over the training set.

    # Put the model into training mode.
    model.train()
    # Reset the total loss
# Out:
# Epoch: 100%|██████████| 4/4 [00:00<00:00, 753.49it/s]

# %%
# Load the new data into a Pandas DataFrame
new_df = pd.read_csv('ChatGPT_text.csv')
new_df.columns
# Out:
# Index(['Unnamed: 0', 'ItemSku', 'text'], dtype='object')

# %%
new_data= new_df[:3]
new_data
# Out:
#    Unnamed: 0      ItemSku                                               text
# 0           0   45019302.0   NON LACTOSE FREE - QUARTO EASY TO DIGEST EASY...
# 1           1   60916700.0   Madelaine December Delights 24 DAYS. 24 SURPR...
# 2           2  285004018.0   GLUTEN FREE LUCKY LEAF Key Lime filling & top...

# %%
# Tokenize the input text
text_x = new_data['text'].tolist()
input_ids = []
attention_masks = []
for text in text_x:
    encoded_dict = tokenizer.encode_plus(
                          text,
                          add_special_tokens = True,
                          max_length = 128,
                          truncation=True,
                          pad_to_max_length = True,
                          return_attention_mask = True,
                          return_tensors = 'pt',
                     )
    input_ids.append(encoded_dict['input_ids'])
    attention_masks.append(encoded_dict['attention_mask'])
input_ids = torch.cat(input_ids, dim=0)
attention_masks = torch.cat(attention_masks, dim=0)
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py:2346: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
# Create the DataLoader for the test set
test_data = TensorDataset(input_ids, attention_masks)
test_sampler = SequentialSampler(test_data)
test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_size)

# Set the model to evaluation mode
model.eval()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Move the input tensors to the GPU
b_input_ids = b_input_ids.to('cuda:0')
b_input_mask = b_input_mask.to('cuda:0')

# Forward pass
with torch.no_grad():
    outputs = model(b_input_ids, token_type_ids=None, attention_mask=b_input_mask)

# %%
# Make predictions on the test set
predictions = []
for batch in test_dataloader:
    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    with torch.no_grad():
        outputs = model(b_input_ids,
                        token_type_ids=None,
                        attention_mask=b_input_mask)
    logits = outputs[0]
    preds = torch.sigmoid(logits)
    preds = preds.detach().cpu().numpy()
    predictions.append(preds)

# %%
predictions
# Out:
# [array([[0.65369195],
#         [0.63444275],
#         [0.5713073 ]], dtype=float32)]

# %%
#TRY NEW

# %%
text = "Tetrapack to keep things fresh. coconut water. fresh and tasty. 3 litres. product of mexico. use within 14 days of opening"
encoded_dict = tokenizer.encode_plus(
                text,                          # Text to encode
                add_special_tokens = True,     # Add '[CLS]' and '[SEP]'
                max_length = 128,              # Pad or truncate all sentences
                truncation=True,
                pad_to_max_length = True,
                return_attention_mask = True,  # Construct attn. masks
                return_tensors = 'pt',         # Return pytorch tensors
           )
input_ids = encoded_dict['input_ids']
attention_mask = encoded_dict['attention_mask']
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py:2346: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
# Set the model to evaluation mode
model.eval()

# Move the model to the same device as the input tensors
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Move the input tensors to the same device as the model
input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)

# Forward pass
with torch.no_grad():
    outputs = model(input_ids=input_ids, attention_mask=attention_mask)
    predicted_class = outputs.logits.argmax().item()


# # Convert the predicted class back to a description
# predicted_description = df[df['MarketingDetails'] == predicted_class]['MarketingDetails'].iloc[0]

# %%
predicted_class
# Out:
# 0
